# %%
import meteogram

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rc('figure', dpi=100)
import matplotlib.dates

import numpy as np

import pandas as pd
# %autoreload 2

# %%
df = meteogram.get_hourly_forecast(url='https://www.yr.no/sted/Finland/S%C3%B6dra_Finland/Helsingfors/')

# %%
fig, ax = plt.subplots(1, 1)

t = df['from_mpl']
T = df['temp'] + 4

ax.plot_date(t, T, '*')
meteogram.plot_temp(t.values, T.values, ax)
ax.bar(df['from_mpl'], df['precip'], align='edge', alpha=0.5, width=1/24)
# Out:
# <Container object of 48 artists>
