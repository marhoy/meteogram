# %%
import locale
locale.setlocale(locale.LC_ALL, 'no_NO.UTF-8')

import meteogram

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rc('figure', dpi=100)
import matplotlib.dates

import numpy as np

import pandas as pd

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
place = '/Norway/Troms/Tromsø/Tromsø/'
place = 'United_States/Texas/Texas_City/'
place = 'Norway/Sør-Trøndelag/Trondheim/Trondheim/'
place = 'Norway/Oslo/Oslo/Godlia/'

df = meteogram.get_hourly_forecast(place=place)
start = 0
df = df[start:start + 18]

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(3.92, 2.34))
ax2 = ax1.twinx()

meteogram.plot_temp(df, ax1)
meteogram.plot_precipitation(df, ax2)
meteogram.format_axes(ax1, ax2)
meteogram.add_weather_symbols(df)
plt.tight_layout(pad=0)
plt.savefig('meteogram.png', format='png')

# %%
dir(fig)
# Out:
# [autoreload of meteogram failed: Traceback (most recent call last):
#   File "/Users/marhoy/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 246, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/marhoy/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 369, in superreload
#     module = reload(module)
#   File "/Users/marhoy/anaconda3/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/Users/marhoy/anaconda3/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/marhoy/GitHub/meteogram/meteogram/__init__.py", line 2, in <module>
# ...
