# %%
import meteogram

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
fig = meteogram.meteogram(bgcolor=[.98, .98, .98])
fig

# %%
import datetime as dt
s = "Updated " + dt.datetime.now().strftime("%H:%M")
# Out:
# 'Updated 10:09'

# %%
t.strftime("%H:%M")
# Out:
# '10:08'

# %%
df = meteogram.get_weather_data.get_hourly_forecast()
df['from_mpl'][0]
# Out:
# 736682.41666666663
