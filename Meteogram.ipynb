# %%
import meteogram

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
fig = meteogram.meteogram(hours=48, size_x=800, place='Norge/Sør-Trøndelag/Trondheim/Trondheim')
fig

# %%
fig = meteogram.meteogram(hours=48, size_x=800, place='Norway/Rogaland/Stavanger/Stavanger/')
ax1, ax2 = fig.get_axes()

fig

# %%
fig = meteogram.meteogram(hours=200, size_x=800)
fig

# %%
import yaml

# %%
with open("config.yaml", 'r') as yamlfile:
    cfg = yaml.load(yamlfile)

# %%
cfg
# Out:
# {'default': {'bgcolor': '(.95, .95, .95)',
#   'dpi': 100,
#   'hours': 18,
#   'locale': 'en_US.UTF-8',
#   'size_h': 392,
#   'size_v': 234,
#   'symbol_interval': 3},
#  'locations': [{'hours': 4, 'place': 'Norway/Oslo/Oslo/Godlia'}]}
